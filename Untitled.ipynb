# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
dataframe = pd.read_csv("Zomato_data.csv")
print(dataframe)
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %%
dataframe
# Out:
#                       name online_order book_table   rate  votes  \
# 0                    Jalsa          Yes        Yes  4.1/5    775
# 1           Spice Elephant          Yes         No  4.1/5    787
# 2          San Churro Cafe          Yes         No  3.8/5    918
# 3    Addhuri Udupi Bhojana           No         No  3.7/5     88
# 4            Grand Village           No         No  3.8/5    166
# ..                     ...          ...        ...    ...    ...
# 143       Melting Melodies           No         No  3.3/5      0
# 144        New Indraprasta           No         No  3.3/5      0
# 145           Anna Kuteera          Yes         No  4.0/5    771
# 146                 Darbar           No         No  3.0/5     98
# 147          Vijayalakshmi          Yes         No  3.9/5     47
#
#      approx_cost(for two people) listed_in(type)
# 0                            800          Buffet
# 1                            800          Buffet
# ...

# %% [markdown]
# convert the data type colum rate - rate

# %%
def handleRate(value):
      value=str(value).split('/')
      value=value[0];
      return float(value);

dataframe['rate']=dataframe['rate'].apply(handleRate)
print(dataframe.head())
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148 entries, 0 to 147
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   name                         148 non-null    object
#  1   online_order                 148 non-null    object
#  2   book_table                   148 non-null    object
#  3   rate                         148 non-null    float64
#  4   votes                        148 non-null    int64
#  5   approx_cost(for two people)  148 non-null    int64
#  6   listed_in(type)              148 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 8.2+ KB

# %%
dataframe.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %% [markdown]
# Conclusion:- Majority of the restaurent fall in dining category

# %%
sns.countplot(x=dataframe['listed_in(type)'], palette="Set2")  # You can try different palettes like "viridis", "coolwarm", etc.
plt.xlabel("Type of Restaurant", color="red", size=20)
plt.ylabel("Count", color="red", size=20)
plt.title("Count of Types of Restaurants", size=24)
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Aditya Dhopte\AppData\Local\Temp\ipykernel_14204\474189096.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=dataframe['listed_in(type)'], palette="Set2")  # You can try different palettes like "viridis", "coolwarm", etc.

# %% [markdown]
# Conclusion:- Majority of the restaurent fall in dining category

# %%
grouped_data = dataframe.groupby('listed_in(type)')['votes'].sum()
result = pd.DataFrame({'votes': grouped_data})

plt.plot(result.index, result['votes'], c="green", marker="o")
plt.xlabel("Types of Restaurant", color="red", size=20)
plt.ylabel("Votes", color="red", size=20)
plt.title("Votes by Type of Restaurant", size=24)
plt.show()

# %% [markdown]
# Conclution:- dining Restaurent has recieved maximum votes .

# %%
counts, bins, patches = plt.hist(dataframe['rate'], bins=5)
for i, patch in enumerate(patches):
    if i % 2 == 0:
        patch.set_facecolor("skyblue") 
    else:
        patch.set_facecolor("orange")

plt.title("Rating Distributions")
plt.xlabel("Rating")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# The majority of restaurant recieved the rating 3.5 to 4.0

# %%
dataframe.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
sns.countplot(x=couple_data, palette="Set2")  # Replace "Set2" with any palette name
plt.xlabel("Approximate Cost (for Two People)")
plt.title("Distribution of Approximate Cost for Two People")
plt.xticks(rotation=45)
plt.show()
# Out:
# C:\Users\Aditya Dhopte\AppData\Local\Temp\ipykernel_14204\2554917517.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=couple_data, palette="Set2")  # Replace "Set2" with any palette name

# %% [markdown]
# The majority of couple order the cost of 300rs

# %%
plt.figure(figsize=(6, 6))
sns.boxplot(x='online_order', y='rate', data=dataframe, hue='online_order', palette="Set2", dodge=False, legend=False)
plt.xlabel("Online Order")
plt.ylabel("Rating")
plt.title("Rating by Online Order")
plt.show()

# %% [markdown]
# offline order recieved low rating as compair to online rating

# %%
dataframe.head()
# Out:
#                     name online_order book_table  rate  votes  \
# 0                  Jalsa          Yes        Yes   4.1    775
# 1         Spice Elephant          Yes         No   4.1    787
# 2        San Churro Cafe          Yes         No   3.8    918
# 3  Addhuri Udupi Bhojana           No         No   3.7     88
# 4          Grand Village           No         No   3.8    166
#
#    approx_cost(for two people) listed_in(type)
# 0                          800          Buffet
# 1                          800          Buffet
# 2                          800          Buffet
# 3                          300          Buffet
# 4                          600          Buffet

# %%
pivot_table = dataframe.pivot_table(index="listed_in(type)", columns="online_order", aggfunc='size', fill_value=0) 
sns.heatmap(pivot_table, annot=True, cmap="YlGnBu", fmt='d')  # Corrected annot=True and cmap
plt.title("Heatmap")
plt.xlabel("Online Order")
plt.ylabel("Listed In (Type)")
plt.show()

# %% [markdown]
# Conclusion: Dining restaurants primarily accept offline orders, while cafes tend to receive more online orders. This indicates that customers prefer in-person ordering at restaurants, whereas they favor online ordering at cafes
